# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/imamuddin/Downloads/bank.csv")

# %%
df['deposit'] = df['deposit'].map({'yes':1,'no':0})

# %%
df['deposit']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 11157    0
# 11158    0
# 11159    0
# 11160    0
# 11161    0
# Name: deposit, Length: 11162, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  str
#  2   marital    11162 non-null  str
#  3   education  11162 non-null  str
#  4   default    11162 non-null  str
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  str
#  7   loan       11162 non-null  str
#  8   contact    11162 non-null  str
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  str
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  str
#  16  deposit    11162 non-null  int64
# dtypes: int64(8), str(9)
# memory usage: 2.0 MB

# %%
df= df.replace('unknown', np.nan)

# %%
df.head()
# Out:
#    age         job  marital  education default  balance housing loan contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no     NaN
# 1   56      admin.  married  secondary      no       45      no   no     NaN
# 2   41  technician  married  secondary      no     1270     yes   no     NaN
# 3   55    services  married  secondary      no     2476     yes   no     NaN
# 4   54      admin.  married   tertiary      no      184      no   no     NaN
#
#    day month  duration  campaign  pdays  previous poutcome  deposit
# 0    5   may      1042         1     -1         0      NaN        1
# 1    5   may      1467         1     -1         0      NaN        1
# 2    5   may      1389         1     -1         0      NaN        1
# 3    5   may       579         1     -1         0      NaN        1
# 4    5   may       673         2     -1         0      NaN        1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11092 non-null  str
#  2   marital    11162 non-null  str
#  3   education  10665 non-null  str
#  4   default    11162 non-null  str
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  str
#  7   loan       11162 non-null  str
#  8   contact    8816 non-null   str
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  str
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   2836 non-null   str
#  16  deposit    11162 non-null  int64
# dtypes: int64(8), str(9)
# memory usage: 1.9 MB

# %%
df.isnull().sum()
# Out:
# age             0
# job            70
# marital         0
# education     497
# default         0
# balance         0
# housing         0
# loan            0
# contact      2346
# day             0
# month           0
# duration        0
# campaign        0
# pdays           0
# previous        0
# poutcome     8326
# deposit         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv('bank_cleaned.csv', index=False)
